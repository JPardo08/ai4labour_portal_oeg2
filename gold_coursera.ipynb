# %% [markdown]
# # GOLD COURSERA

# %%
# GOLD = {
#     "Train personnel on proper operational procedures.": {
#         "positives": [
#             "Training and Development",
#             "Instructional Design"
#         ],
#         "negatives": [
#             "Application Security",
#             "network defensive tactics"
#         ]
#     },
#     "Prepare procedural documents.": {
#         "positives": [
#             "Technical Writing",
#             "Business Process Management"
#         ],
#         "negatives": [
#             "Cybersecurity",
#             "threat intelligence"
#         ]
#     },
#     "Recommend technical design or process changes to improve efficiency, quality, or performance.": {
#         "positives": [
#             "Process Improvement",
#             "Systems Design"
#         ],
#         "negatives": [
#             "Digital Marketing",
#             "Human Resources Analytics"
#         ]
#     },
#     "Confer with technical personnel to prepare designs or operational plans.": {
#         "positives": [
#             "Collaboration",
#             "Engineering Design"
#         ],
#         "negatives": [
#             "Customer Service",
#             "Accounting"
#         ]
#     },
#     "Communicate technical information to suppliers, contractors, or regulatory agencies.": {
#         "positives": [
#             "Technical Communication",
#             "Supply Chain Management"
#         ],
#         "negatives": [
#             "Public Health",
#             "Psychology"
#         ]
#     },
#     "Design medical devices or appliances.": {
#         "positives": [
#             "Python Programming",
#             "Software Development"
#         ],
#         "negatives": [
#             "Human Resources Management",
#             "Biology"
#         ]
#     },
#     "Research engineering aspects of biological or chemical processes.": {
#         "positives": [
#             "Quality Assurance",
#             "Six Sigma"
#         ],
#         "negatives": [
#             "Digital Illustration",
#             "Cybersecurity"
#         ]
#     },
#     "Devise research or testing protocols.": {
#         "positives": [
#             "Financial Analysis",
#             "Cost Accounting"
#         ],
#         "negatives": [
#             "Graphic Design",
#             "Art History"
#         ]
#     },
#     "Develop operational methods or processes that use green materials or emphasize sustainability.": {
#         "positives": [
#             "Leadership",
#             "Project Management"
#         ],
#         "negatives": [
#             "Neuroscience",
#             "Social Media Marketing"
#         ]
#     },
#     "Develop technical methods or processes.": {
#         "positives": [
#             "Biochemical Engineering",
#             "Chemical Engineering"
#         ],
#         "negatives": [
#             "Financial Markets",
#             "Tourism"
#         ]
#     }
# }

# %% [markdown]
# Tras analizarlo hemos visto que habian 8 samples disponibles. Y esto se debe a que muchas de las skills no aparecian dentro de la lista de skills.csv.
#
# Por ello hemos modificado la lista por la que viene a continuacion
# - Las skills son bastante mas sencillas que las dwas, por ello la longitud se mueve entre 1 hasta 3 palabras, con una media de 2 o 1 en la mayoria de casos.
# - A diferencia del GOLD de dwas, en este si que estan totalmente idos,
# es decir, no comparten apenas una palabra como mucho, con la dwa dada.
#
# Tras ver como ha ido la segunda vuelta, parecen ser skills bastante genericas.

# %%
# GOLD = {
#     "Train personnel on proper operational procedures.": {
#         "positives": [
#             "Instructional Design",
#             "Leadership"
#         ],
#         "negatives": [
#             "Application Security",
#             "network defensive tactics"
#         ]
#     },
#     "Prepare procedural documents.": {
#         "positives": [
#             "Process Improvement",
#             "Project Management"
#         ],
#         "negatives": [
#             "Cybersecurity",
#             "threat intelligence"
#         ]
#     },
#     "Recommend technical design or process changes to improve efficiency, quality, or performance.": {
#         "positives": [
#             "Systems Design",
#             "Six Sigma"
#         ],
#         "negatives": [
#             "Digital Marketing",
#             "Social Media Marketing"
#         ]
#     },
#     "Confer with technical personnel to prepare designs or operational plans.": {
#         "positives": [
#             "Collaboration",
#             "Engineering Design"
#         ],
#         "negatives": [
#             "Customer Service",
#             "Accounting"
#         ]
#     },
#     "Communicate technical information to suppliers, contractors, or regulatory agencies.": {
#         "positives": [
#             "Financial Analysis",
#             "Cost Accounting"
#         ],
#         "negatives": [
#             "Public Health",
#             "Psychology"
#         ]
#     },
#     "Design medical devices or appliances.": {
#         "positives": [
#             "Python Programming",
#             "Software Development"
#         ],
#         "negatives": [
#             "Public Health",
#             "Biology"
#         ]
#     },
#     "Research engineering aspects of biological or chemical processes.": {
#         "positives": [
#             "Chemical Engineering",
#             "Biology"
#         ],
#         "negatives": [
#             "Cybersecurity",
#             "Graphic Design"
#         ]
#     },
#     "Devise research or testing protocols.": {
#         "positives": [
#             "Financial Analysis",
#             "Cost Accounting"
#         ],
#         "negatives": [
#             "Graphic Design",
#             "Art History"
#         ]
#     },
#     "Develop operational methods or processes that use green materials or emphasize sustainability.": {
#         "positives": [
#             "Leadership",
#             "Project Management"
#         ],
#         "negatives": [
#             "Neuroscience",
#             "Social Media Marketing"
#         ]
#     },
#     "Develop technical methods or processes.": {
#         "positives": [
#             "Chemical Engineering",
#             "Software Development"
#         ],
#         "negatives": [
#             "Financial Markets",
#             "Art History"
#         ]
#     }
# }

# %% [markdown]
# Con la funcion de repetidos de abajo tenemos los siguientes resultados:
#
# - Skill(s): ['Leadership']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Develop operational methods or processes that use green materials or emphasize sustainability.', 'Train personnel on proper operational procedures.']
# - Skill(s): ['Project Management']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Develop operational methods or processes that use green materials or emphasize sustainability.', 'Prepare procedural documents.']
# - Skill(s): ['Cybersecurity']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Prepare procedural documents.', 'Research engineering aspects of biological or chemical processes.']
# - Skill(s): ['Social Media Marketing']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Develop operational methods or processes that use green materials or emphasize sustainability.', 'Recommend technical design or process changes to improve efficiency, quality, or performance.']
# - Skill(s): ['Financial Analysis']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Communicate technical information to suppliers, contractors, or regulatory agencies.', 'Devise research or testing protocols.']
# - Skill(s): ['Cost Accounting']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Communicate technical information to suppliers, contractors, or regulatory agencies.', 'Devise research or testing protocols.']
# - Skill(s): ['Public Health']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Communicate technical information to suppliers, contractors, or regulatory agencies.', 'Design medical devices or appliances.']
# - Skill(s): ['Software Development']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Design medical devices or appliances.', 'Develop technical methods or processes.']
# - Skill(s): ['Biology']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Design medical devices or appliances.', 'Research engineering aspects of biological or chemical processes.']
# - Skill(s): ['Chemical Engineering']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Develop technical methods or processes.', 'Research engineering aspects of biological or chemical processes.']
# - Skill(s): ['Graphic Design']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Devise research or testing protocols.', 'Research engineering aspects of biological or chemical processes.']
# - Skill(s): ['Art History']
#   - DICCIONARIOS: [0]
#   - PARES: []
#   - QUERIES: ['Develop technical methods or processes.', 'Devise research or testing protocols.']
#
# Lo que nos viene a indicar que hay skills que se repiten entre distintas queries del mismo diccionario. Procedemos a modificarlo.

# %%
GOLD = {
  "train personnel on proper operational procedures": {
    "positives": [
      "instructional design",
      "leadership"
    ],
    "negatives": [
      "application security",
      "network defensive tactics"
    ]
  },
  "prepare procedural documents": {
    "positives": [
      "process improvement",
      "project management"
    ],
    "negatives": [
      "cybersecurity",
      "threat intelligence"
    ]
  },
  "recommend technical design or process changes to improve efficiency, quality, or performance": {
    "positives": [
      "systems design",
      "six sigma"
    ],
    "negatives": [
      "digital marketing",
      "social media marketing"
    ]
  },
  "confer with technical personnel to prepare designs or operational plans": {
    "positives": [
      "collaboration",
      "engineering design"
    ],
    "negatives": [
      "customer service",
      "accounting"
    ]
  },
  "communicate technical information to suppliers, contractors, or regulatory agencies": {
    "positives": [
      "financial analysis",
      "cost accounting"
    ],
    "negatives": [
      "public health",
      "psychology"
    ]
  },
  "design medical devices or appliances": {
    "positives": [
      "python programming",
      "software development"
    ],
    "negatives": [
      "5g",
      "biology"
    ]
  },
  "research engineering aspects of biological or chemical processes": {
    "positives": [
      "chemical engineering",
      "engineering"
    ],
    "negatives": [
      "ai/ml",
      "graphic design"
    ]
  },
  "devise research or testing protocols": {
    "positives": [
      "a/b testing",
      "a/b/n testing"
    ],
    "negatives": [
      "c++",
      "art history"
    ]
  },
  "develop operational methods or processes that use green materials or emphasize sustainability": {
    "positives": [
      "raw materials and processes",
      "develop communication processes during change management planning"
    ],
    "negatives": [
      "neuroscience",
      "c++11"
    ]
  },
  "develop technical methods or processes": {
    "positives": [
      "methods",
      "5d and 3d integration methods"
    ],
    "negatives": [
      "financial markets",
      "c/c++"
    ]
  }
}

# %% [markdown]
# Con ≈10 queries la evaluación queda sub-muestreada y las métricas se cuantizan (0.1, 0.05…), sobre todo en DWA→Skill (Coursera), por eso la leaderboard sale “plana”.
#
# Pero lo de que “hasta 10 queries son 40 DWAs usadas” no es correcto: los k (1,3,5,10) no aumentan el nº de queries; solo cambian el corte de evaluación. Si evalúas con 10 queries, son 10 DWAs (no 40). Tener varios k te da varias métricas por las mismas 10 queries.
#
# Para que la leaderboard es plana: no es un problema de cómo calculas las métricas; es el **tamaño del conjunto de validación**. Con **221 queries** vas bien para ambos pipelines; con **10** no.

# %% [markdown]
# ### Qué es “óptimo” aquí
#
# En la Information retrieval (IR) se promedian métricas por query; la precisión estadística depende de cuántas queries tengas (no de cuántos documentos haya en el índice). Con 221 DWAs disponibles, tu límite natural es 221 queries para ambos pipelines (en DWA→Skill las queries siguen siendo DWAs; las 5315 skills son los documentos, no las unidades de muestreo).
#
# * **IR** = *Information Retrieval* → “Recuperación de Información”.
#   Es el área que estudia cómo buscar y rankear documentos, pasajes, skills... a partir de queries. Todas las métricas que estás usando (P\@k, R\@k, MAP, MRR, nDCG) vienen de ahí: se evalúan **por query** y luego se hace un promedio.
#
# Un cálculo rápido (peor caso, varianza máxima en \[0,1]) para estimar la media de una métrica como nDCG/MAP con margen de error ±e al 95%:
#
# $$
# n \;\gtrsim\; \frac{z_{0.95}^2}{4\,e^2} \quad \text{con } z_{0.95}=1{.}96
# $$
#
# * **±0.10** → **n ≈ 96** queries
# * **±0.07** → **n ≈ 196** queries
# * **±0.05** → **n ≈ 385** queries (no alcanzable con 221 DWAs)
#
# Conclusiones:
# * Con **todas las 221 DWAs** obtienes, en peor caso, un margen \~**±0.066** a 95% (muchísimo mejor que ±0.1).
# * Con **10 queries** el margen es enorme (≈±0.31 peor caso): de ahí los “números redondos” y empates.
#
# ### Nota sobre “representatividad” en Coursera
#
# Que haya 5315 skills no cambia el tamaño muestral necesario: lo que manda es el nº de queries (DWAs). Para cubrir mejor la variabilidad de skills:
#
# * asegúrate de que el GOLD por DWA tenga suficientes skills relevantes (si no, abundan ceros),
# * y estratifica las queries para que sus relevantes cubran clusters de skills distintos (o reporta métricas por estratos y un macro-promedio).
#
# Aunque el IC no cambie por sí mismo, el valor de las métricas y su varianza entre queries pueden moverse:
#
# 1. Más distractores ⇒ la tarea suele volverse más difícil → bajan P\@k/MAP/nDCG si el sistema no mejora.
# 2. GOLD incompleto puede sesgar más: con más skills es más probable que haya relevantes no juzgados que cuentan como “no relevantes”.
#
# Solución: pooling (fusionar top-k de varios sistemas) y anotar esos candidatos.
#
#
# 3. Umbral/calibración: con un índice mayor, el umbral óptimo (H2) y los pesos β\_BM25/γ\_Jaccard pueden desplazarse.
# 4. Representatividad: más skills ⇒ más heterogeneidad. No sube el n óptimo por fórmula, pero conviene estratificar queries para cubrir nuevas “familias” de skills.

# %% [markdown]
# ### Recomendación práctica
#
# * **Usa todas las 221 DWAs como queries** para ambos pipelines. Es tu “óptimo” real con el corpus actual.
# * Si por coste tienes que muestrear, apunta a **≥100 queries** (te deja \~±0.10) y **estratifica** por:
#
#   * área/IWA,
#   * longitud de la DWA,
#   * frecuencia/cobertura en GOLD.
#     Así evitas que 2–3 queries “raras” sesguen todo.
#
# Reporta Intervalo de confianza del 95% por sistema (bootstrap por query) y usa tests pareados (approx. randomization/boostrap) para decidir empates. Rompe empates con orden nDCG\@10 → MAP\@10 → MRR → R\@1 → coverage\_rel\@10.
#
# * **IC** = *Intervalo de Confianza*. Es un rango estadístico que te dice en qué valores puede estar la “verdadera” media de tu métrica con cierta probabilidad (típicamente 95%).
#
# Ejemplo: si con 221 queries tu `nDCG@10` medio es **0.42** y el IC95% es \[0.39, 0.45], significa que con un 95% de confianza el valor real está en ese rango.
#
# El problema de Coursera no era la fórmula de las métricas (IR), sino que con tan pocas queries el **IC es enorme** (±0.3 con 10 queries). Eso genera resultados “redondos” y empates. Con más queries, el IC se estrecha y la leaderboard empieza a diferenciar modelos.

# %% [markdown]
# ## Preparacion GOLD

# %%
import pandas as pd
DATA_DIR = "/Users/jpardo/Desktop/Proyectos/AI4LABOUR/ai4labour_preprocess/Mejoras/data"

dwas = DATA_DIR + "/dwas.csv"
courses = DATA_DIR + "/courses_plain.csv"

# print(dwas)
# print(courses)

dwas_df = pd.read_csv(dwas, sep="\t")
courses_df = pd.read_csv(courses, sep="\t")

dwas_list=dwas_df['dwa_title'].tolist()
courses_list=courses_df['skill_title'].tolist()

# %%
from pprint import pprint

pprint(dwas_list)
# Out:
# ['train personnel on proper operational procedures',
#  'prepare procedural documents',
#  'recommend technical design or process changes to improve efficiency, '
#  'quality, or performance',
#  'confer with technical personnel to prepare designs or operational plans',
#  'communicate technical information to suppliers, contractors, or regulatory '
#  'agencies',
#  'design medical devices or appliances',
#  'research engineering aspects of biological or chemical processes',
#  'devise research or testing protocols',
#  'develop operational methods or processes that use green materials or '
#  'emphasize sustainability',
#  'develop technical methods or processes',
#  'create models of engineering designs or methods',
#  'maintain operational records or records systems',
#  'supervise engineering or other technical personnel',
#  'estimate operational costs',
#  'estimate time requirements for development or production projects',
#  'prepare detailed work plans',
# ...

# %%
pprint(courses_list)
# Out:
# ['application security',
#  'threat intelligence',
#  'network defensive tactics',
#  'security analyst',
#  'cybersecurity',
#  'cyberattacks',
#  'network security',
#  'threat',
#  'risk',
#  'information assurance',
#  'security',
#  'governance',
#  'opportunity identification',
#  'strategic thinking',
#  'business analytics',
#  'entrepreneurship',
#  'emotional intelligence',
#  'customer relationship management (crm)',
#  'communication',
#  'bargaining',
#  'negotiation',
#  'income statement analysis',
#  'balance sheet',
#  'financial terminology',
#  'financial statement use and analysis',
#  'financial ratio analysis',
#  'leadership',
#  'strategic planning',
#  'vision statement development',
#  'business culture analysis',
#  'customer value proposition (cvp) development',
#  'strategic pricing',
#  'competitive advantage analysis',
#  'competitive analysis',
#  'financial management',
#  'cash flow cycle analysis',
#  'cash flow forecast analysis',
# ...

# %%
print(f"DWAS = {len(dwas_list)}| SKILLS = {len(courses_list)}")
# Out:
# DWAS = 221| SKILLS = 5304

# %%
# Contar valores
conteo_dwas = dwas_df["dwa_title"].value_counts()
print(conteo_dwas)

# Filtrar solo los que se repiten
repetidos_dwas = conteo_dwas[conteo_dwas > 1]
print(repetidos_dwas)
# Out:
# dwa_title
# train personnel on proper operational procedures                                    1
# monitor activities affecting environmental quality                                  1
# research advanced engineering designs or applications                               1
# coordinate activities with suppliers, contractors, clients, or other departments    1
# conduct quantitative failure analyses of operational data                           1
#                                                                                    ..
# prepare proposal documents                                                          1
# supervise production or support personnel                                           1
# perform marketing activities                                                        1
# advise others on logistics topics                                                   1
# interpret design or operational test results                                        1
# ...

# %%
# Contar valores
conteo_coursera = courses_df["skill_title"].value_counts()
print(conteo_coursera)

# Filtrar solo los que se repiten
repetidos_coursera = conteo_coursera[conteo_coursera > 1]
print(repetidos_coursera)
# Out:
# skill_title
# application security                         1
# workstations                                 1
# source code                                  1
# music career                                 1
# setting up your teaching studio              1
#                                             ..
# infographics                                 1
# use navigation in your apps                  1
# build a simple ui using the layout editor    1
# compose ui using kotlin ui views             1
# rexx                                         1
# Name: count, Length: 5304, dtype: int64
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Check
# Comprobacion si todas las dwas y las skilss estan dentro de las dwas permitidas

# %%
def check(GOLD, dwas_list, courses_list):
    for i in GOLD.keys():
        if i in dwas_list:
            # print(i)
            print(f'CHECK DWA {i}')
        else:
            print(f'WARN DWA {i}')

        for j in GOLD[i]['positives']:
            if j in courses_list:
                # print(j)
                print(f'CHECKS SKILL + {j}')
            else:
                # print(j)
                print(f'WARN SKILL + {j}')

        for h in GOLD[i]['negatives']:
            if h in courses_list:
                # print(h)
                print(f'CHECKS SKILL - {h}')
            else:
                # print(h)
                print(f'WARN SKILL - {h}')
        
        print('-'*50)

# %%
check(GOLD, dwas_list, courses_list)
# Out:
# CHECK DWA train personnel on proper operational procedures
# CHECKS SKILL + instructional design
# CHECKS SKILL + leadership
# CHECKS SKILL - application security
# CHECKS SKILL - network defensive tactics
# --------------------------------------------------
# CHECK DWA prepare procedural documents
# CHECKS SKILL + process improvement
# CHECKS SKILL + project management
# CHECKS SKILL - cybersecurity
# CHECKS SKILL - threat intelligence
# --------------------------------------------------
# CHECK DWA recommend technical design or process changes to improve efficiency, quality, or performance
# CHECKS SKILL + systems design
# CHECKS SKILL + six sigma
# CHECKS SKILL - digital marketing
# CHECKS SKILL - social media marketing
# --------------------------------------------------
# CHECK DWA confer with technical personnel to prepare designs or operational plans
# CHECKS SKILL + collaboration
# CHECKS SKILL + engineering design
# CHECKS SKILL - customer service
# ...

# %% [markdown]
# Cuidado con 2.5d -> 5d

# %%
from collections import defaultdict
from itertools import combinations
from typing import List, Dict, Any

def _norm(s: str) -> str:
    """Normaliza texto para comparar: recorta espacios y pasa a minúsculas."""
    return " ".join(str(s).split()).strip().lower()

def find_gold_duplicates(gold_list: List[Dict[str, Dict[str, List[str]]]]) -> Dict[str, Any]:
    """
    Analiza una lista de diccionarios GOLD y devuelve duplicados:
      - duplicate_queries: queries (DWAs) repetidas y dónde aparecen.
      - duplicate_skills: skills repetidas globalmente y en qué queries/buckets.
      - duplicate_skills_within_query: skills repetidas dentro de la misma query.
      - pairs_*: pares (i, j) de índices de GOLD que comparten elementos repetidos.

    Parámetro
    ---------
    gold_list: [GOLD_dict, GOLD_dict, ...]
        Cada GOLD_dict tiene la forma:
        {
          "Query A": {"positives": [...], "negatives": [...]},
          "Query B": {"positives": [...], "negatives": [...]},
          ...
        }

    Retorna
    -------
    dict con claves:
      {
        "duplicate_queries": [
          {
            "query_norm": str,
            "occurrences": [{"gold_idx": int, "query": str}],
            "pairs": [(int, int), ...]
          }, ...
        ],
        "duplicate_skills": [
          {
            "skill_norm": str,
            "occurrences": [
              {"gold_idx": int, "query": str, "bucket": "positives|negatives", "skill": str}
            ],
            "pairs": [(int, int), ...],
            "queries_involved": [str, ...]  # queries únicas donde aparece
          }, ...
        ],
        "duplicate_skills_within_query": [
          {
            "gold_idx": int,
            "query": str,
            "duplicates": [
              {"skill_norm": str, "originals": [str, ...], "buckets": ["positives|negatives", ...]}
            ]
          }, ...
        ]
      }
    """
    # --- Índices de aparición ---
    query_locs = defaultdict(list)   # q_norm -> [{"gold_idx", "query"}...]
    skill_locs = defaultdict(list)   # s_norm -> [{"gold_idx", "query", "bucket", "skill"}...]

    # --- Duplicados dentro de una misma query ---
    dup_within_query = []

    for gold_idx, gold in enumerate(gold_list):
        if not isinstance(gold, dict):
            continue  # ignora entradas que no sean diccionarios

        for query, payload in gold.items():
            q_norm = _norm(query)
            query_locs[q_norm].append({"gold_idx": gold_idx, "query": query})

            pos = list(map(str, payload.get("positives", []) or []))
            neg = list(map(str, payload.get("negatives", []) or []))

            # Registra localizaciones globales por skill
            for s in pos:
                skill_locs[_norm(s)].append({
                    "gold_idx": gold_idx, "query": query, "bucket": "positives", "skill": s
                })
            for s in neg:
                skill_locs[_norm(s)].append({
                    "gold_idx": gold_idx, "query": query, "bucket": "negatives", "skill": s
                })

            # Detecta duplicados dentro de la misma query (positives, negatives o cruzados)
            bucket_tagged = [("positives", s) for s in pos] + [("negatives", s) for s in neg]
            counts = defaultdict(lambda: {"originals": [], "buckets": []})
            for b, s in bucket_tagged:
                ns = _norm(s)
                counts[ns]["originals"].append(s)
                counts[ns]["buckets"].append(b)

            dups_here = []
            for ns, info in counts.items():
                if len(info["originals"]) > 1:
                    dups_here.append({
                        "skill_norm": ns,
                        "originals": info["originals"],
                        "buckets": info["buckets"]
                    })
            if dups_here:
                dup_within_query.append({
                    "gold_idx": gold_idx,
                    "query": query,
                    "duplicates": dups_here
                })

    # --- Queries repetidas entre GOLDs ---
    duplicate_queries = []
    for qn, locs in query_locs.items():
        if len(locs) > 1:
            # pares de índices (i, j) donde aparece
            idxs = sorted({loc["gold_idx"] for loc in locs})
            pairs = sorted(set(combinations(idxs, 2)))
            duplicate_queries.append({
                "query_norm": qn,
                "occurrences": locs,
                "pairs": pairs
            })

    # --- Skills repetidas globalmente entre GOLDs (y/o entre queries) ---
    duplicate_skills = []
    for sn, locs in skill_locs.items():
        if len(locs) > 1:
            idxs = sorted({loc["gold_idx"] for loc in locs})
            pairs = sorted(set(combinations(idxs, 2)))
            queries_involved = sorted({loc["query"] for loc in locs})
            duplicate_skills.append({
                "skill_norm": sn,
                "occurrences": locs,
                "pairs": pairs,
                "queries_involved": queries_involved
            })

    return {
        "duplicate_queries": duplicate_queries,
        "duplicate_skills": duplicate_skills,
        "duplicate_skills_within_query": dup_within_query
    }


def pretty_print_duplicates(report: Dict[str, Any]) -> None:
    """Imprime un resumen legible del informe de duplicados."""
    dq = report.get("duplicate_queries", [])
    ds = report.get("duplicate_skills", [])
    dw = report.get("duplicate_skills_within_query", [])

    print("=== QUERIES REPETIDAS ENTRE DICCIONARIOS ===")
    if not dq:
        print("✔ No hay queries repetidas.")
    else:
        for item in dq:
            qs = ", ".join(sorted({occ["query"] for occ in item["occurrences"]}))
            idxs = sorted({occ["gold_idx"] for occ in item["occurrences"]})
            print(f"- Query: {qs}")
            print(f"  · DICCIONARIOS: {idxs}")
            print(f"  · PARES: {item['pairs']}")

    print("\n=== SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===")
    if not ds:
        print("✔ No hay skills repetidas.")
    else:
        for item in ds:
            skills_orig = sorted({occ["skill"] for occ in item["occurrences"]})
            idxs = sorted({occ["gold_idx"] for occ in item["occurrences"]})
            queries = item["queries_involved"]
            print(f"- Skill(s): {skills_orig}")
            print(f"  · DICCIONARIOS: {idxs}")
            print(f"  · PARES: {item['pairs']}")
            print(f"  · QUERIES: {queries}")

    print("\n=== SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===")
    if not dw:
        print("✔ No hay duplicados internos dentro de las queries.")
    else:
        for item in dw:
            print(f"- GOLD #{item['gold_idx']} · Query: {item['query']}")
            for d in item["duplicates"]:
                print(f"  · Skill_norm: {d['skill_norm']}")
                print(f"    Originals: {d['originals']}")
                print(f"    Buckets: {d['buckets']}")

# %%
GOLD2= {
  "create models of engineering designs or methods": {
    "positives": [
      "assembly methods",
      "attention models"
    ],
    "negatives": [
      "security analyst",
      "cyberattacks"
    ]
  },
  "maintain operational records or records systems": {
    "positives": [
      "pv systems",
      "control systems"
    ],
    "negatives": [
      "network security",
      "threat"
    ]
  },
  "supervise engineering or other technical personnel": {
    "positives": [
      "aquaculture engineering",
      "civil engineering"
    ],
    "negatives": [
      "risk",
      "information assurance"
    ]
  },
  "estimate operational costs": {
    "positives": [
      "cost estimate",
      "sunk costs"
    ],
    "negatives": [
      "security",
      "governance"
    ]
  },
  "estimate time requirements for development or production projects": {
    "positives": [
      "production",
      "ui development"
    ],
    "negatives": [
      "opportunity identification",
      "strategic thinking"
    ]
  },
  "prepare detailed work plans": {
    "positives": [
      "prepare a detailed sales call plan",
      "prepare data"
    ],
    "negatives": [
      "business analytics",
      "entrepreneurship"
    ]
  },
  "prepare technical reports for internal use": {
    "positives": [
      "reports",
      "design reports"
    ],
    "negatives": [
      "emotional intelligence",
      "customer relationship management (crm)"
    ]
  },
  "prepare contracts, disclosures, or applications": {
    "positives": [
      "contracts",
      "back-end applications"
    ],
    "negatives": [
      "communication",
      "bargaining"
    ]
  },
  "update technical knowledge": {
    "positives": [
      "gst technical",
      "it skills and knowledge"
    ],
    "negatives": [
      "negotiation",
      "income statement analysis"
    ]
  },
  "evaluate characteristics of equipment or systems": {
    "positives": [
      "ar characteristics",
      "defining systems"
    ],
    "negatives": [
      "balance sheet",
      "financial terminology"
    ]
  }
}

# %%
check(GOLD2, dwas_list, courses_list)
# Out:
# CHECK DWA create models of engineering designs or methods
# CHECKS SKILL + assembly methods
# CHECKS SKILL + attention models
# CHECKS SKILL - security analyst
# CHECKS SKILL - cyberattacks
# --------------------------------------------------
# CHECK DWA maintain operational records or records systems
# CHECKS SKILL + pv systems
# CHECKS SKILL + control systems
# CHECKS SKILL - network security
# CHECKS SKILL - threat
# --------------------------------------------------
# CHECK DWA supervise engineering or other technical personnel
# CHECKS SKILL + aquaculture engineering
# CHECKS SKILL + civil engineering
# CHECKS SKILL - risk
# CHECKS SKILL - information assurance
# --------------------------------------------------
# CHECK DWA estimate operational costs
# CHECKS SKILL + cost estimate
# CHECKS SKILL + sunk costs
# CHECKS SKILL - security
# CHECKS SKILL - governance
# --------------------------------------------------
# ...

# %%
gold_list = [GOLD, GOLD2]

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD3 = {
  "evaluate quality of materials or products": {
    "positives": ["quality management", "quality assessment"],
    "negatives": ["content marketing", "public speaking"]
  },
  "test products for functionality or quality": {
    "positives": ["nondestructive testing (ndt)", "software testing"],
    "negatives": ["nutrition", "photography"]
  },
  "conduct validation tests of equipment or processes": {
    "positives": ["validation", "system testing"],
    "negatives": ["creative writing", "music theory"]
  },
  "analyze test or validation data": {
    "positives": ["statistical analysis", "data analysis"],
    "negatives": ["public relations", "b2b sales"]
  },
  "analyze operational data to evaluate operations, processes or products": {
    "positives": ["data visualization (dataviz)", "exploratory data analysis"],
    "negatives": ["brand identity and management", "social media analytics"]
  },
  "implement design or process improvements": {
    "positives": ["process optimization", "lean manufacturing"],
    "negatives": ["child psychology", "intercultural communication"]
  },
  "design industrial processing systems": {
    "positives": ["process control", "statistical process control (spc)"],
    "negatives": ["copywriting", "storytelling"]
  },
  "create physical models or prototypes": {
    "positives": ["rapid prototyping", "3d printing"],
    "negatives": ["financial accounting", "history"]
  },
  "evaluate environmental impact of operational or development activities": {
    "positives": ["environmental impact assessment", "air quality monitoring"],
    "negatives": ["retail management", "brand management"]
  },
  "prepare scientific or technical reports or presentations": {
    "positives": ["report building", "dashboarding and reporting"],
    "negatives": ["music production", "philosophy of science"]
  }
}

# %%
check(GOLD3, dwas_list, courses_list)
# Out:
# CHECK DWA evaluate quality of materials or products
# CHECKS SKILL + quality management
# CHECKS SKILL + quality assessment
# CHECKS SKILL - content marketing
# CHECKS SKILL - public speaking
# --------------------------------------------------
# CHECK DWA test products for functionality or quality
# CHECKS SKILL + nondestructive testing (ndt)
# CHECKS SKILL + software testing
# CHECKS SKILL - nutrition
# CHECKS SKILL - photography
# --------------------------------------------------
# CHECK DWA conduct validation tests of equipment or processes
# CHECKS SKILL + validation
# CHECKS SKILL + system testing
# CHECKS SKILL - creative writing
# CHECKS SKILL - music theory
# --------------------------------------------------
# CHECK DWA analyze test or validation data
# CHECKS SKILL + statistical analysis
# CHECKS SKILL + data analysis
# CHECKS SKILL - public relations
# CHECKS SKILL - b2b sales
# --------------------------------------------------
# ...

# %%
gold_list.append(GOLD3)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD4 = {
  "develop software or computer applications": {
    "positives": ["android software development", "scrum (software development)"],
    "negatives": ["poetry", "poetry writing"]
  },
  "conduct environmental audits": {
    "positives": ["environmental impacts", "sustainability"],
    "negatives": ["teaching creative writing", "literature"]
  },
  "maintain regulatory or compliance documentation": {
    "positives": ["data documentation", "compliance"],
    "negatives": ["shakespeare", "appreciate richness of shakespearean language"]
  },
  "prepare operational reports": {
    "positives": ["data reporting", "reports and dashboards"],
    "negatives": ["guitar scales", "guitar chords"]
  },
  "supervise employees": {
    "positives": ["leadership development", "leadership and management"],
    "negatives": ["guitar", "playing guitar"]
  },
  "prepare operational budgets": {
    "positives": ["capital budgeting", "budgeting techniques for cost and profit centers"],
    "negatives": ["piano", "piano performance"]
  },
  "analyze data to inform operational decisions or activities": {
    "positives": ["business intelligence", "data-driven decision making"],
    "negatives": ["illustration", "digital fashion design"]
  },
  "coordinate safety or regulatory compliance activities": {
    "positives": ["risk management", "food safety"],
    "negatives": ["3d fashion design", "on-demand fashion design"]
  },
  "design control systems for mechanical or other equipment": {
    "positives": ["pid control", "automation"],
    "negatives": ["cooking vegetables in ways that will delight", "cooking"]
  },
  "direct installation activities": {
    "positives": ["verify an ansible installation", "electrical commissioning"],
    "negatives": ["psychotherapy", "mindfulness"]
  }
}

# %%
check(GOLD4, dwas_list, courses_list)
# Out:
# CHECK DWA develop software or computer applications
# CHECKS SKILL + android software development
# CHECKS SKILL + scrum (software development)
# CHECKS SKILL - poetry
# CHECKS SKILL - poetry writing
# --------------------------------------------------
# CHECK DWA conduct environmental audits
# CHECKS SKILL + environmental impacts
# CHECKS SKILL + sustainability
# CHECKS SKILL - teaching creative writing
# CHECKS SKILL - literature
# --------------------------------------------------
# CHECK DWA maintain regulatory or compliance documentation
# CHECKS SKILL + data documentation
# CHECKS SKILL + compliance
# CHECKS SKILL - shakespeare
# CHECKS SKILL - appreciate richness of shakespearean language
# --------------------------------------------------
# CHECK DWA prepare operational reports
# CHECKS SKILL + data reporting
# CHECKS SKILL + reports and dashboards
# CHECKS SKILL - guitar scales
# CHECKS SKILL - guitar chords
# --------------------------------------------------
# ...

# %%
gold_list.append(GOLD4)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD5 = {
  "administer compensation or benefits programs": {
    "positives": [
      "compensation and benefits",
      "compensation analysis"
    ],
    "negatives": [
      ".bit",
      ".net"
    ]
  },
  "administer standardized physical or psychological tests": {
    "positives": [
      "acquire skills in generating a wide range of creative ideas and techniques that can be applied with safety to encourage innovative thinking and solution exploration",
      "assessing ones level of anxiety (resilience and burnout) using self-assessment tests"
    ],
    "negatives": [
      ".net architecture",
      ".net core"
    ]
  },
  "advise customers on technical or procedural issues": {
    "positives": [
      "analyzing technical and financial possibilities",
      "designing rpa technical specification documents"
    ],
    "negatives": [
      ".net framework",
      "2-d arrays"
    ]
  },
  "advise customers on the use of products or services": {
    "positives": [
      "5g services and architecture",
      "amazon web services (amazon aws)"
    ],
    "negatives": [
      "2d & 3d design",
      "2d computer graphics"
    ]
  },
  "advise others on career or personal development": {
    "positives": [
      "career development",
      "personal development"
    ],
    "negatives": [
      "360-degree video",
      "3d computer graphics"
    ]
  },
  "advise others on legal or regulatory compliance matters": {
    "positives": [
      "legal compliance",
      "regulatory compliance"
    ],
    "negatives": [
      "3d modeling",
      "4g technology"
    ]
  },
  "advise others on logistics topics": {
    "positives": [
      "communicating with others in person",
      "distribution and logistics"
    ],
    "negatives": [
      "4th amendment",
      "80/20 rule of social media"
    ]
  },
  "advise others regarding green practices or environmental concerns": {
    "positives": [
      "greater understanding of environmental concerns",
      "educational practices"
    ],
    "negatives": [
      "a basic understanding of epidemiological theory",
      "a basic understanding of matrices and probability"
    ]
  },
  "analyze biological samples": {
    "positives": [
      "ability to analyze and discuss key financial statements",
      "ability to analyze and interpret the financial impact of different transactions on the financial position and performance of a company"
    ],
    "negatives": [
      "a general understanding of traditional chinese medicine and indian ayurveda",
      "a* search algorithm"
    ]
  },
  "analyze chemical compounds or substances": {
    "positives": [
      "analyze data from a continuous measurement system for sources of variation capability",
      "analyze a data breach"
    ],
    "negatives": [
      "a/b testing and model deployment",
      "abductive reasoning"
    ]
  }
}

# %%
check(GOLD5, dwas_list, courses_list)
# Out:
# CHECK DWA administer compensation or benefits programs
# CHECKS SKILL + compensation and benefits
# CHECKS SKILL + compensation analysis
# CHECKS SKILL - .bit
# CHECKS SKILL - .net
# --------------------------------------------------
# CHECK DWA administer standardized physical or psychological tests
# WARN SKILL + acquire skills in generating a wide range of creative ideas and techniques that can be applied with safety to encourage innovative thinking and solution exploration
# CHECKS SKILL + assessing ones level of anxiety (resilience and burnout) using self-assessment tests
# CHECKS SKILL - .net architecture
# CHECKS SKILL - .net core
# --------------------------------------------------
# CHECK DWA advise customers on technical or procedural issues
# CHECKS SKILL + analyzing technical and financial possibilities
# CHECKS SKILL + designing rpa technical specification documents
# CHECKS SKILL - .net framework
# CHECKS SKILL - 2-d arrays
# ...

# %%
gold_list.append(GOLD5)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD6 = {
  "research methods to improve food products": {
    "positives": [
      "big data products",
      "food"
    ],
    "negatives": [
      "robotic mapping",
      "particle filter"
    ]
  },
  "analyze logistics processes": {
    "positives": [
      "international logistics",
      "logistics planning"
    ],
    "negatives": [
      "linear scheduling method",
      "finite-state machine"
    ]
  },
  "cultivate micro-organisms for study, testing, or medical preparations": {
    "positives": [
      "qa and testing",
      "automated testing"
    ],
    "negatives": [
      "microcontroller",
      "project planning and analysis"
    ]
  },
  "test quality of materials or finished products": {
    "positives": [
      "materials",
      "materials research"
    ],
    "negatives": [
      "kotlin",
      "hypothesis-driven development"
    ]
  },
  "maintain knowledge of current developments in area of expertise": {
    "positives": [
      "expertise in data science",
      "voltage and current sensors"
    ],
    "negatives": [
      "understand how to identify customers who have predispositions but no desired behavior",
      "calibration in machine learning models"
    ]
  },
  "design structures or facilities": {
    "positives": [
      "graph data structures",
      "organizational structures"
    ],
    "negatives": [
      "r and rstudio",
      "ticketing systems"
    ]
  },
  "recommend organizational process or policy changes": {
    "positives": [
      "environmental policy",
      "organizational change"
    ],
    "negatives": [
      "earth economics",
      "crt0"
    ]
  },
  "assemble equipment or components": {
    "positives": [
      "components of gans",
      "analyzing story components"
    ],
    "negatives": [
      "jquery",
      "confounding"
    ]
  },
  "analyze data to assess operational or project effectiveness": {
    "positives": [
      "project",
      "project operations"
    ],
    "negatives": [
      "apposition",
      "conditionals (computer science)"
    ]
  },
  "evaluate employee performance": {
    "positives": [
      "performance",
      "performance management"
    ],
    "negatives": [
      "synchronous communication request-response model",
      "externality"
    ]
  }
}

# %%
check(GOLD6, dwas_list, courses_list)
# Out:
# CHECK DWA research methods to improve food products
# CHECKS SKILL + big data products
# CHECKS SKILL + food
# CHECKS SKILL - robotic mapping
# CHECKS SKILL - particle filter
# --------------------------------------------------
# CHECK DWA analyze logistics processes
# CHECKS SKILL + international logistics
# CHECKS SKILL + logistics planning
# CHECKS SKILL - linear scheduling method
# CHECKS SKILL - finite-state machine
# --------------------------------------------------
# CHECK DWA cultivate micro-organisms for study, testing, or medical preparations
# CHECKS SKILL + qa and testing
# CHECKS SKILL + automated testing
# CHECKS SKILL - microcontroller
# CHECKS SKILL - project planning and analysis
# --------------------------------------------------
# CHECK DWA test quality of materials or finished products
# CHECKS SKILL + materials
# CHECKS SKILL + materials research
# CHECKS SKILL - kotlin
# CHECKS SKILL - hypothesis-driven development
# ...

# %%
gold_list.append(GOLD6)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD7 = {
  "investigate the environmental impact of projects": {
    "positives": ["market impact", "impact assessment"],
    "negatives": ["vestibular system", "gst compliances"]
  },
  "fabricate devices or components": {
    "positives": ["mobile devices", "display devices"],
    "negatives": ["interacting with github", "medical billing"]
  },
  "research industrial processes or operations": {
    "positives": ["research", "ux research"],
    "negatives": ["luxury goods", "marketing supply chain finance services"]
  },
  "design energy-efficient vehicles or vehicle components": {
    "positives": ["electric vehicles", "laptop and mobile components"],
    "negatives": ["microservice architecture", "survivorship"]
  },
  "identify opportunities to improve operational efficiency": {
    "positives": ["explain the concept of blank space to identify opportunities", "market efficiency"],
    "negatives": ["big data transmission", "loan"]
  },
  "design industrial equipment": {
    "positives": ["industrial iot", "personal protective equipment"],
    "negatives": ["certification prep", "reaction wheels"]
  },
  "monitor activities affecting environmental quality": {
    "positives": ["quality", "data quality"],
    "negatives": ["threat model", "green washing"]
  },
  "collect samples of raw materials or finished products": {
    "positives": ["materials safety", "materials planning"],
    "negatives": ["real-time tracing", "computational thinking"]
  },
  "manage inventories of products or organizational resources": {
    "positives": ["natural resources", "human resources (hr)"],
    "negatives": ["system operation", "red hat linux"]
  },
  "prepare reports related to compliance matters": {
    "positives": ["sez compliance", "safety compliance"],
    "negatives": ["digital circuit design", "health equity"]
  }
}

# %%
check(GOLD7, dwas_list, courses_list)
# Out:
# CHECK DWA investigate the environmental impact of projects
# CHECKS SKILL + market impact
# CHECKS SKILL + impact assessment
# CHECKS SKILL - vestibular system
# CHECKS SKILL - gst compliances
# --------------------------------------------------
# CHECK DWA fabricate devices or components
# CHECKS SKILL + mobile devices
# CHECKS SKILL + display devices
# CHECKS SKILL - interacting with github
# CHECKS SKILL - medical billing
# --------------------------------------------------
# CHECK DWA research industrial processes or operations
# CHECKS SKILL + research
# CHECKS SKILL + ux research
# CHECKS SKILL - luxury goods
# CHECKS SKILL - marketing supply chain finance services
# --------------------------------------------------
# CHECK DWA design energy-efficient vehicles or vehicle components
# CHECKS SKILL + electric vehicles
# CHECKS SKILL + laptop and mobile components
# CHECKS SKILL - microservice architecture
# CHECKS SKILL - survivorship
# ...

# %%
gold_list.append(GOLD7)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD8 = {
  "direct operational or production activities": {
    "positives": [
      "video production",
      "video pre-production"
    ],
    "negatives": [
      "financial statement use and analysis",
      "financial ratio analysis"
    ]
  },
  "respond to emergencies to provide assistance": {
    "positives": [
      "psychological first aid",
      "incident response playbooks"
    ],
    "negatives": [
      "strategic planning",
      "vision statement development"
    ]
  },
  "monitor external affairs or events affecting business operations": {
    "positives": [
      "business culture analysis",
      "operations management"
    ],
    "negatives": [
      "customer value proposition (cvp) development",
      "strategic pricing"
    ]
  },
  "direct sales, marketing, or customer service activities": {
    "positives": [
      "sales management",
      "marketing management"
    ],
    "negatives": [
      "competitive advantage analysis",
      "competitive analysis"
    ]
  },
  "direct organizational operations, projects, or services": {
    "positives": [
      "services based interfaces and architecture (sbi/sba)",
      "how organizational leaders are ultimately accountable for meeting commitments"
    ],
    "negatives": [
      "financial management",
      "cash flow cycle analysis"
    ]
  },
  "monitor organizational procedures to ensure proper functioning": {
    "positives": [
      "principles and procedures related to share-based compensation",
      "accounting organizational skills"
    ],
    "negatives": [
      "cash flow forecast analysis",
      "market research"
    ]
  },
  "confer with organizational members to accomplish work activities": {
    "positives": [
      "stakeholder communication",
      "digital collaboration"
    ],
    "negatives": [
      "value proposition analysis",
      "process management"
    ]
  },
  "conduct employee training programs": {
    "positives": [
      "prevention programs",
      "training"
    ],
    "negatives": [
      "business modelling",
      "business culture development"
    ]
  },
  "manage control system activities in organizations": {
    "positives": [
      "manufacturing process management",
      "mobility management"
    ],
    "negatives": [
      "funding requirement analysis",
      "funding applications"
    ]
  },
  "maintain personnel records": {
    "positives": [
      "maintaining individual accountability",
      "electronic health records"
    ],
    "negatives": [
      "strategic financial planning",
      "analytics"
    ]
  }
}

# %%
check(GOLD8, dwas_list, courses_list)
# Out:
# CHECK DWA direct operational or production activities
# CHECKS SKILL + video production
# CHECKS SKILL + video pre-production
# CHECKS SKILL - financial statement use and analysis
# CHECKS SKILL - financial ratio analysis
# --------------------------------------------------
# CHECK DWA respond to emergencies to provide assistance
# CHECKS SKILL + psychological first aid
# CHECKS SKILL + incident response playbooks
# CHECKS SKILL - strategic planning
# CHECKS SKILL - vision statement development
# --------------------------------------------------
# CHECK DWA monitor external affairs or events affecting business operations
# CHECKS SKILL + business culture analysis
# CHECKS SKILL + operations management
# CHECKS SKILL - customer value proposition (cvp) development
# CHECKS SKILL - strategic pricing
# --------------------------------------------------
# CHECK DWA direct sales, marketing, or customer service activities
# CHECKS SKILL + sales management
# ...

# %%
gold_list.append(GOLD8)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD9 = {
  "negotiate sales or lease agreements for products or services": {
    "positives": [
      "contract negotiations",
      "sales strategy"
    ],
    "negatives": [
      "calculus",
      "linear algebra"
    ]
  },
  "develop specifications for new products or processes": {
    "positives": [
      "requirements analysis",
      "requirements engineering"
    ],
    "negatives": [
      "cartography",
      "paleontology"
    ]
  },
  "hire personnel": {
    "positives": [
      "recruitment",
      "interviewing skills"
    ],
    "negatives": [
      "philosophy",
      "astrophysics"
    ]
  },
  "prepare operational progress or status reports": {
    "positives": [
      "news reporting",
      "sustainability reporting & esg metrics"
    ],
    "negatives": [
      "ceramics",
      "chemistry"
    ]
  },
  "develop operating strategies, plans, or procedures": {
    "positives": [
      "business strategy",
      "strategy implementation"
    ],
    "negatives": [
      "entomology",
      "linguistics"
    ]
  },
  "maintain data in information systems or databases": {
    "positives": [
      "database administration",
      "database management"
    ],
    "negatives": [
      "syntax",
      "astronomy"
    ]
  },
  "establish organizational guidelines or policies": {
    "positives": [
      "policy development",
      "icma principles and guidelines"
    ],
    "negatives": [
      "geology",
      "ecology"
    ]
  },
  "determine causes of operational problems or failures": {
    "positives": [
      "troubleshooting",
      "advanced troubleshooting"
    ],
    "negatives": [
      "screenwriting",
      "geography"
    ]
  },
  "monitor the productivity or efficiency of industrial operations": {
    "positives": [
      "productivity",
      "personal productivity"
    ],
    "negatives": [
      "sociology",
      "economics"
    ]
  },
  "purchase materials, equipment, or other resources": {
    "positives": [
      "procurement",
      "procurement contracts"
    ],
    "negatives": [
      "statistics",
      "classical music"
    ]
  }
}

# %%
check(GOLD9, dwas_list, courses_list)
# Out:
# CHECK DWA negotiate sales or lease agreements for products or services
# CHECKS SKILL + contract negotiations
# CHECKS SKILL + sales strategy
# CHECKS SKILL - calculus
# CHECKS SKILL - linear algebra
# --------------------------------------------------
# CHECK DWA develop specifications for new products or processes
# CHECKS SKILL + requirements analysis
# CHECKS SKILL + requirements engineering
# CHECKS SKILL - cartography
# CHECKS SKILL - paleontology
# --------------------------------------------------
# CHECK DWA hire personnel
# CHECKS SKILL + recruitment
# CHECKS SKILL + interviewing skills
# CHECKS SKILL - philosophy
# CHECKS SKILL - astrophysics
# --------------------------------------------------
# CHECK DWA prepare operational progress or status reports
# CHECKS SKILL + news reporting
# CHECKS SKILL + sustainability reporting & esg metrics
# CHECKS SKILL - ceramics
# CHECKS SKILL - chemistry
# --------------------------------------------------
# ...

# %%
gold_list.append(GOLD9)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
GOLD10 = {
  "maintain test equipment": {
    "positives": [
      "concept testing",
      "test-driven development"
    ],
    "negatives": [
      "database optimization",
      "understand consumer insights from social media messages"
    ]
  },
  "identify opportunities for green initiatives": {
    "positives": [
      "interpret eps data analyze its implications for investors and other stakeholders identify factors that may impact eps calculations and calculate both basic and diluted eps using relevant financial data",
      "identify and describe the various components of shareholders' equity and be able to interpret and analyze equity-related information in financial statements effectively including the principles and procedures related to share-based compensation"
    ],
    "negatives": [
      "processor design",
      "set up a youtube channel"
    ]
  },
  "install production equipment or systems": {
    "positives": [
      "energy systems principles",
      "healthcare systems analysis"
    ],
    "negatives": [
      "wordpress",
      "task estimation"
    ]
  },
  "explain engineering drawings, specifications, or other technical information": {
    "positives": [
      "mechanical engineering",
      "material engineering"
    ],
    "negatives": [
      "future forecasting",
      "aws database"
    ]
  },
  "analyze green technology design requirements": {
    "positives": [
      "marketing design",
      "computer-aided design (cad)"
    ],
    "negatives": [
      "p values",
      "restconf"
    ]
  },
  "program robotic equipment": {
    "positives": [
      "midi programming",
      "r programming"
    ],
    "negatives": [
      "interpretation",
      "camera model"
    ]
  },
  "direct facility maintenance or repair activities": {
    "positives": [
      "classify cash flow activities into operating investing and financing activities and define the indirect and direct methods of calculating cash flows from operating activities",
      "hybrid learning activities"
    ],
    "negatives": [
      "analytic mindset",
      "hardware planning"
    ]
  },
  "implement transportation changes to reduce environmental impact": {
    "positives": [
      "recognize different types of accounting changes e.g. changes in principle estimate and error corrections and demonstrate how to apply retrospective and prospective approaches when dealing with accounting changes",
      "ability to analyze and interpret the financial impact of different liability transactions on the financial position and performance of a company"
    ],
    "negatives": [
      "mathematics",
      "cybersecurity threats"
    ]
  },
  "estimate technical or resource requirements for development or production projects": {
    "positives": [
      "marketing strategy development",
      "product development"
    ],
    "negatives": [
      "password",
      "use the rest api explorer"
    ]
  },
  "interpret design or operational test results": {
    "positives": [
      "product design processes",
      "unit testing"
    ],
    "negatives": [
      "network cryptography",
      "assessing your balance"
    ]
  }
}

# %%
check(GOLD10, dwas_list, courses_list)
# Out:
# CHECK DWA maintain test equipment
# CHECKS SKILL + concept testing
# CHECKS SKILL + test-driven development
# CHECKS SKILL - database optimization
# CHECKS SKILL - understand consumer insights from social media messages
# --------------------------------------------------
# CHECK DWA identify opportunities for green initiatives
# CHECKS SKILL + interpret eps data analyze its implications for investors and other stakeholders identify factors that may impact eps calculations and calculate both basic and diluted eps using relevant financial data
# CHECKS SKILL + identify and describe the various components of shareholders' equity and be able to interpret and analyze equity-related information in financial statements effectively including the principles and procedures related to share-based compensation
# CHECKS SKILL - processor design
# CHECKS SKILL - set up a youtube channel
# --------------------------------------------------
# CHECK DWA install production equipment or systems
# ...

# %%
gold_list.append(GOLD10)

report = find_gold_duplicates(gold_list)
pretty_print_duplicates(report)

# Si prefieres inspeccionarlo como dict:
# from pprint import pprint
# pprint(report)
# Out:
# === QUERIES REPETIDAS ENTRE DICCIONARIOS ===
# ✔ No hay queries repetidas.
#
# === SKILLS REPETIDAS ENTRE DICCIONARIOS/QUERIES ===
# ✔ No hay skills repetidas.
#
# === SKILLS DUPLICADAS DENTRO DE LA MISMA QUERY ===
# ✔ No hay duplicados internos dentro de las queries.

# %%
def merge_gold_dicts(gold_dicts):
    """
    Recibe una lista de diccionarios GOLD y devuelve uno solo con todos los pares.
    Asume que las queries (claves) ya están normalizadas y no se repiten entre diccionarios.
    """
    merged = {}
    for gold in gold_dicts:
        for query, pairs in gold.items():
            if query in merged:
                raise ValueError(f"Query duplicada encontrada: {query}")
            merged[query] = pairs
    return merged

# %%
# Ejemplo de uso:
GOLD_FINAL = merge_gold_dicts(gold_list)
print(len(GOLD_FINAL))   # nº total de queries en el gold estándar unificado
# Out:
# 100

# %%
pprint(GOLD_FINAL)
# Out:
# {'administer compensation or benefits programs': {'negatives': ['.bit', '.net'],
#                                                   'positives': ['compensation '
#                                                                 'and benefits',
#                                                                 'compensation '
#                                                                 'analysis']},
#  'administer standardized physical or psychological tests': {'negatives': ['.net '
#                                                                            'architecture',
#                                                                            '.net '
#                                                                            'core'],
#                                                              'positives': ['acquire '
#                                                                            'skills '
# ...

# %% [markdown]
# ## Guardar el gold estandard

# %%
import json
from pathlib import Path

GOLD_PATH = DATA_DIR + "/gold_coursera_base.json"
GOLD_FLAT_CSV = DATA_DIR + "/gold_flat_coursera.csv"

# %%
# Guardar GOLD (dict) a JSON -> COMENTAR UNA VEZ EJECU
with open(GOLD_PATH, "w", encoding="utf-8") as f:
    json.dump(GOLD_FINAL, f, ensure_ascii=False, indent=2)
print(f"[F] GOLD guardado en: {GOLD_PATH}")
# Out:
# [F] GOLD guardado en: /Users/jpardo/Desktop/Proyectos/AI4LABOUR/ai4labour_preprocess/Mejoras/data/gold_coursera.json

# %%
# # (Opcional) Versión plana a CSV para inspección
import pandas as pd
rows = []
for q_text, dd in GOLD_FINAL.items():
    for p in dd.get("positives", []):
        rows.append({"query_text": q_text, "cand_text": p, "label": "positive"})
    for n in dd.get("negatives", []):
        rows.append({"query_text": q_text, "cand_text": n, "label": "negative"})
pd.DataFrame(rows).to_csv(GOLD_FLAT_CSV, index=False)
print(f"[F] GOLD plano guardado en: {GOLD_FLAT_CSV}")
# Out:
# [F] GOLD plano guardado en: /Users/jpardo/Desktop/Proyectos/AI4LABOUR/ai4labour_preprocess/Mejoras/data/gold_flat_coursera.csv

# %% [markdown]
# ## Diferencias entre el analisis manual

# %%
gold = GOLD_PATH
gold_corregido = DATA_DIR + "/gold_coursera.json"

# %%
# Volver a cargar (si lo necesitas)
with open(gold, "r", encoding="utf-8") as f:
    GOLD_FINAL_BASE = json.load(f)

# %%
with open(gold_corregido, "r", encoding="utf-8") as f:
    GOLD_FINAL_CORREGIDO = json.load(f)

# %%
print(f"QUERIES GOLD = {len(GOLD_FINAL_BASE)} | QUERIES GOLD = {len(GOLD_FINAL_CORREGIDO)}")
# Out:
# QUERIES GOLD = 100 | QUERIES GOLD = 86

# %%
100-86
# Out:
# 14

# %% [markdown]
# Tras las revision manual, se decide eliminar aquellas queries ambiguas con el fin de no meter ruido al modelo. Aunque parezcan pocas, son bastantes con respecto el numero de dwas disponibles. En este aso y a diferencia de dwa-skill, tenemos mas margen de maniobra.

# %% [markdown]
# ## Dentro del notebook de ejecucion

# %%
# import json
# from pathlib import Path

# GOLD_PATH = DATA_DIR / "gold_coursera.json"
# # GOLD_FLAT_CSV = DATA_DIR / "gold_flat_coursera.csv"

# %%
# # Volver a cargar (si lo necesitas)
# with open(GOLD_PATH, "r", encoding="utf-8") as f:
#     GOLD = json.load(f)

# %% [markdown]
# ## En local

# %%
# import pandas as pd

# _courses = "/Users/jpardo/Desktop/Proyectos/AI4LABOUR/ai4labour_preprocess/Mejoras/data/courses_plain.csv" 
# _dwas = "/Users/jpardo/Desktop/Proyectos/AI4LABOUR/ai4labour_preprocess/Mejoras/data/dwas.csv" 

# _courses_df=pd.read_csv(_courses)['skill_title'].tolist()
# _dwas_df=pd.read_csv(_dwas)['dwa_title'].tolist()

# display(_courses_df)
# display(_dwas_df)

# print(_courses_df)
# print(_dwas_df)
